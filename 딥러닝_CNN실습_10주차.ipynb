# %% [markdown]
# <a href="https://colab.research.google.com/github/rlawnsqja2/2024-1-my-BDA/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D_CNN%EC%8B%A4%EC%8A%B5_10%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import tensorflow as tf
import os
import PIL
import shutil

# 기본 경로
base_dir = './OX_images/'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# 훈련용 O/X 이미지 경로
train_o_dir = os.path.join(train_dir, 'O')
train_x_dir = os.path.join(train_dir, 'X')
print(train_o_dir, train_x_dir)

# 검증용 O/X 이미지 경로
validation_o_dir = os.path.join(validation_dir, 'O')
validation_x_dir = os.path.join(validation_dir, 'X')
print(validation_o_dir, validation_x_dir)

# 테스트용 O/X 이미지 경로
test_o_dir = os.path.join(test_dir, 'O')
test_x_dir = os.path.join(test_dir, 'X')
print(test_o_dir, test_x_dir)
# Out:
# ./OX_images/train/O ./OX_images/train/X
# ./OX_images/validation/O ./OX_images/validation/X
# ./OX_images/test/O ./OX_images/test/X

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# 훈련용 이미지 파일 이름 조회
train_o_fnames = os.listdir(train_o_dir)
train_x_fnames = os.listdir(train_x_dir)
print(train_o_fnames)
print(train_x_fnames)
# Out:
# ['20223618-O1.png', '20220371 6.png', '20232502._3.png', '20231563_o5.png', '20232882-o2.png', '20223618-O20.png', '20223618-O3.png', '20231576O8.png', '20223618-O18.png', '20231575_O_05.png', '20231559.o10.png', '20231559.o1.png', '20223618-O17.png', '20231567_O5.png', '20221667-2.png', '2023156510.png', '20232505_o1.png', '20221667-3.png', '20220371 8.png', '20231559.o6.png', '202315658.png', '20223618-O8.png', '202315657.png', '202315655.png', '20231567_O2.png', '20231566_o.png', '20232877-9.png', '20232505_o4.png', '202315656.png', '20223618-O5.png', '20232877-5.png', '20232882-o6.png', '원1.png', '202315651.png', '20223618-O14.png', '20220371 7.png', '20232882-o9.png', '20232882-o7.png', '20232877-7.png', '20220371 5.png', '20223618-O10.png', '20232882-o8.png', '20232502_6.png', '20223618-O9.png', '20232505_o2.png', '20232877-2.png', '20231576O4.png', '202315654.png', '20232502._4.png', '20231575_O_02.png', '202315652.png', '20231576O10.png', '20231567_O3.png', '20232882-o1.png', '20231563_o8.png', '20231568O5.png', '20231559.o5.png', '20221667-1.png', '20223618-O7.png', '20231575_O_04.png', '20231576O6.png', '20223618-O13.png', '20223618-O12.png', '20232882-o4.png', '20231563_o6.png', '20232505_o7.png', '20232505_o8.png', '20232505_o9.png', '20231563_o10.png', '202315653.png', '20231575_O_09.png', '20210829-O10.png', '20220371 3.png', '20223618-O19.png', '20231575_O_07.png', '20231575_O_10.png', '20231559.o2.png', '20231563_o2.png', '20232877.png', '20231567_O7.png', '20231567_O4.png', '20223618-O16.png', '20231563_o4.png', '20223618-O11.png', '20220371 10.png', '20231568O4.png', '원3.png', '20221667-4.png', '20221667-9.png', '원2.png', '20223618-O15.png', '20231576O5.png', '20231559.o3.png', '20220371 2.png', '20232882-o5.png', '20221667-10.png', '20231563_o7.png', '20223618-O2.png', '20231559.o9.png', '20231567_O6.png', '20232502_8.png', '20231576O1.png', '20231575_O_03.png', '20232882-o3.png', '20231563_o3.png', '20232505_o3.png', '20231563_o1.png', '20231559.o8.png', '20231567_O8.png', '20232505_o6.png', '20231567_O9.png', '20221667-7.png', '20231576O7.png', '20231559.o4.png', '20231568O1.png', '20223618-O4.png', '20232882-o10.png', '20231567_O10.png', '20232505_o10.png', '20221667-6.png', '20231575_O_06.png', '20231576O2.png', '20231575_O_08.png', '20231567_O1.png', '20231563_o9.png', '20231575_O_01.png', '20220371 1.png', '20231568O3.png', '20231576O3.png', '20220371 9.png', '20232505_o5.png', '20231559.o7.png', '20221667-8.png', '20232502.png', '202315659.png', '20223618-O6.png', '20221667-5.png', '20220371 4.png', '20231576O9.png', '20231568O2.png']
# ['20232502_10.png', '20232877-1.png', '2023156512.png', '20231559.x5.png', '20231575_X_09.png', '20231566_x5.png', '20231575_X_04.png', '20231566_x.png', '20231576X7.png', '20231563_x4.png', '20231563_x2.png', '20231576X4.png', '20223618-X9.png', '20231563_x8.png', '20231563_x5.png', '20221667X-6.png', '20231559.x8.png', '20231575_X_03.png', '20232877-4.png', '20231568X5.png', '20223618-X7.png', '20231575_X_07.png', '20223618-X14.png', '20223618-X4.png', '20232505_x1.png', '20221667X-10.png', '20231566_x7.png', '20231576X3(1).png', '20231563_x6.png', '2023156514.png', '20231567_X4.png', '20232882-x3.png', '20221667X-9.png', '20221667X-7.png', '20231567_X5.png', '20231567_X10.png', '20231575_X_01.png', '20231566_x4.png', '2023156515.png', '20223618-X10.png', '20223618-X13.png', '20231567_X6.png', '20231575_X_10.png', '20221667X--8.png', '20231576X6(1).png', '20232882-x7.png', '20223618-X20.png', '20231567_X8.png', '20231559.x6.png', '20231563_x1.png', '20231576X10.png', '20221667X-2.png', '20232505_x9.png', '20232505_x4.png', '20231576X9.png', '20232882-x8.png', '20231559.x1.png', '2023156516.png', '20231563_x7.png', '20231567_X7.png', '20232877-10.png', '20231559.x9.png', '20231559.x3.png', '20232502_9.png', '20223618-X6.png', '20223618-X18.png', '20232505_x2.png', '20231568X1.png', '20221667X-1.png', '20232882-x6.png', '20231576X10(1).png', '20231576X8(1).png', '20232505_x3.png', '20232505_x8.png', '20231576X5(1).png', '2023156513.png', '20221667X-4.png', '20232882-x5.png', '20231559.x10.png', '20223618-X5.png', '20231575_X_06.png', '20231568X4.png', '20231576X9(1).png', '20221667X-3.png', '20231576X2.png', '20232505_x5.png', '20232882-x2.png', '20232505_x7.png', '20232882-x4.png', '20231559.x7.png', '20223618-X1.png', '20231566_x1.png', '2023156511.png', '20231559.x4.png', '20231563_x3.png', '20221667X-5.png', '20220371 10.png', '20231576X1(1).png', '20232502_7.png', '20232882-x10.png', '20231575_X_02.png', '20231576X3.png', '20231576X6.png', '20231567_X9.png', '20231567_X2.png', '20223618-X17.png', '20223618-X2.png', '20223618-X11.png', '20232882-x1.png', '20223618-X19.png', '20223618-X3.png', '20231568X3.png', '20231568X2.png', '20231567_X1.png', '20231576X1.png', '20231576X8.png', '20231576X4(1).png', '20232882-x9.png', '20231566_x6.png', '20231566_x3.png', '20232505_x6.png', '20223618-X15.png', '20231567_X3.png', '20231576X5.png', '20231563_x10.png', '20223618-X12.png', '20231559.x2.png', '20231576X7(1).png', '20231563_x9.png', '20231575_X_08.png', '20232502_5.png', '20223618-X16.png', '20231566_x2.png', '20220371 9.png', '20232505_x10.png', '20231576X2(1).png', '20223618-X8.png', '20232877-6.png', '20231575_X_05.png', '20232502_2.png']

# %%
print('Total training o images :', len(os.listdir(train_o_dir)))
print('Total training x images :', len(os.listdir(train_x_dir)))

print('Total validation o images :', len(os.listdir(validation_o_dir)))
print('Total validation x images :', len(os.listdir(validation_x_dir)))

print('Total test o images :', len(os.listdir(test_o_dir)))
print('Total test x images :', len(os.listdir(test_x_dir)))
# Out:
# Total training o images : 140
# Total training x images : 140
# Total validation o images : 19
# Total validation x images : 20
# Total test o images : 20
# Total test x images : 20

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_o_pix = [os.path.join(train_o_dir, fname) for fname in train_o_fnames[pic_index-8:pic_index]]
next_x_pix = [os.path.join(train_x_dir, fname) for fname in train_x_fnames[pic_index-8:pic_index]]

for i, img_path in enumerate(next_o_pix+next_x_pix):
  sp = plt.subplot(nrows, ncols, i+1)
  sp.axis('OFF')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
# 이미지 데이터 전처리
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# image augmentation
# train셋에만 적용
train_datagen = ImageDataGenerator(rescale = 1./255, # 모든 이미지 원소값 들을 255로 나누기
                                   rotation_range=25, # 0~25도 사이에서 임의의 각도로 원본이미지를 회전
                                   width_shift_range=0.05, # 0.05범위 내에서 임의의 값만큼 임의의 방향으로 좌우 이동
                                   height_shift_range=0.05, # 0.05범위 내에서 임의의 값만큼 임의의 방향으로 상하 이동
                                   zoom_range=0.2, # (1-0.2)~(1+0.2) => 0.8~1.2 사이에서 임의의 수치만큼 확대/축소
                                   horizontal_flip=True, # 좌우로 뒤집기
                                   vertical_flip=True,
                                   fill_mode='nearest'
                                   )
# validation 및 test 이미지는 augmentation을 적용하지 않는다;
# 모델 성능을 평가할 때에는 이미지 원본을 사용 (rescale만 진행)
validation_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
import os

folder_path = './OX_images/validation/.ipynb_checkpoints'

if os.path.exists(folder_path):
  shutil.rmtree(folder_path)
  print("Folder deleted successfully.")
else:
  print("Folder not found.")

folder_path = './OX_images/train/.ipynb_checkpoints'

if os.path.exists(folder_path):
  shutil.rmtree(folder_path)
  print("Folder deleted successfully.")
else:
  print("Folder not found.")

folder_path = './OX_images/test/.ipynb_checkpoints'

if os.path.exists(folder_path):
  shutil.rmtree(folder_path)
  print("Folder deleted successfully.")
else:
  print("Folder not found.")
# Out:
# Folder not found.
# Folder not found.
# Folder not found.

# %%
# flow_from_directory() 메서드를 이용해서 훈련과 테스트에 사용될 이미지 데이터를 만들기
# 변환된 이미지 데이터 생성
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=16, # 한번에 변환된 이미지 16개씩 만들어라 라는 것
                                                    color_mode='grayscale', # 흑백 이미지 처리
                                                    class_mode='binary',
                                                    target_size=(150,150)) # target_size에 맞춰서 이미지의 크기가 조절된다
validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                              batch_size=4,
                                                              color_mode='grayscale',
                                                              class_mode='binary',
                                                              target_size=(150,150))
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  batch_size=4,
                                                  color_mode='grayscale',
                                                  class_mode='binary',
                                                  target_size=(150,150))
# 참고로, generator 생성시 batch_size x steps_per_epoch (model fit에서) <= 훈련 샘플 수 보다 작거나 같아야 한다.
# Out:
# Found 280 images belonging to 2 classes.
# Found 39 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
# class 확인
train_generator.class_indices
# Out:
# {'O': 0, 'X': 1}

# %%
# 이미지 하나 불러오기 (Augmentation 적용확인)
sample_img = mpimg.imread(next_o_pix[0])
plt.imshow(sample_img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
max_iter = 4
cnt = 1
sample_img2 = sample_img[np.newaxis, ...]

plt.figure(figsize=(10,10))
for img in train_datagen.flow(sample_img2):
  plt.subplot(1, max_iter, cnt)
  plt.imshow(image.array_to_img(img[0]))
  if cnt == max_iter:
    break
  cnt += 1

# %%
# 합성곱 신경망 모델 구성하기
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary() # 신경망의 구조 확인
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 148, 148, 16)      160
#
#  max_pooling2d_3 (MaxPoolin  (None, 74, 74, 16)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_4 (MaxPoolin  (None, 36, 36, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 34, 34, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9248)              0
#
#  dense_2 (Dense)             (None, 512)               4735488
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 4750049 (18.12 MB)
# Trainable params: 4750049 (18.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# compile() 메서드를 이용해서 손실 함수 (loss function)와 옵티마이저 (optimizer)를 지정
model.compile(optimizer=RMSprop(learning_rate=0.001), # 옵티마이저로는 RMSprop 사용
              loss='binary_crossentropy', # 손실 함수로 ‘binary_crossentropy’ 사용
              metrics= ['accuracy'])
# RMSprop (Root Mean Square Propagation) Algorithm: 훈련 과정 중에 학습률을 적절하게 변화시킨다.

# %%
# 모델 훈련
history = model.fit_generator(train_generator, # train_generator안에 X값, y값 다 있으니 generator만 주면 된다
                              validation_data=validation_generator, # validatino_generator안에도 검증용 X,y데이터들이 다 있으니 generator로 주면 됨
                              steps_per_epoch=4, # 한 번의 에포크(epoch)에서 훈련에 사용할 배치(batch)의 개수 지정; generator를 4번 부르겠다
                              epochs=100, # 데이터셋을 한 번 훈련하는 과정; epoch은 100 이상은 줘야한다
                              validation_steps=4, # 한 번의 에포크가 끝날 때, 검증에 사용되는 배치(batch)의 개수를 지정;
                                                  # validation_generator를 4번 불러서 나온 이미지들로 작업을 해라
                              verbose=2)
# 참고: validation_steps는 보통 내가 원하는 이미지 수에 flow할 때 지정한 batchsize로 나눈 값을 validation_steps로 지정
# Out:
# Epoch 1/100
# <ipython-input-106-c83d59ad84b8>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, # train_generator안에 X값, y값 다 있으니 generator만 주면 된다
# 4/4 - 3s - loss: 2.8868 - accuracy: 0.4107 - val_loss: 0.6955 - val_accuracy: 0.5000 - 3s/epoch - 678ms/step
# Epoch 2/100
# 4/4 - 2s - loss: 0.7172 - accuracy: 0.4375 - val_loss: 0.7102 - val_accuracy: 0.4375 - 2s/epoch - 406ms/step
# Epoch 3/100
# 4/4 - 3s - loss: 0.6724 - accuracy: 0.5938 - val_loss: 0.7757 - val_accuracy: 0.3750 - 3s/epoch - 636ms/step
# Epoch 4/100
# 4/4 - 3s - loss: 0.7049 - accuracy: 0.4688 - val_loss: 0.6941 - val_accuracy: 0.4375 - 3s/epoch - 772ms/step
# Epoch 5/100
# 4/4 - 3s - loss: 0.6729 - accuracy: 0.6964 - val_loss: 0.6644 - val_accuracy: 0.5625 - 3s/epoch - 866ms/step
# Epoch 6/100
# 4/4 - 2s - loss: 0.6877 - accuracy: 0.5000 - val_loss: 0.6405 - val_accuracy: 0.5000 - 2s/epoch - 404ms/step
# Epoch 7/100
# 4/4 - 1s - loss: 0.6159 - accuracy: 0.7143 - val_loss: 0.5127 - val_accuracy: 0.8125 - 1s/epoch - 326ms/step
# Epoch 8/100
# 4/4 - 2s - loss: 0.5839 - accuracy: 0.7031 - val_loss: 0.3774 - val_accuracy: 1.0000 - 2s/epoch - 396ms/step
# Epoch 9/100
# 4/4 - 2s - loss: 0.5843 - accuracy: 0.7656 - val_loss: 0.3344 - val_accuracy: 0.8750 - 2s/epoch - 390ms/step
# Epoch 10/100
# 4/4 - 2s - loss: 0.5184 - accuracy: 0.7344 - val_loss: 0.2379 - val_accuracy: 1.0000 - 2s/epoch - 498ms/step
# Epoch 11/100
# 4/4 - 2s - loss: 0.3722 - accuracy: 0.8438 - val_loss: 0.2594 - val_accuracy: 0.9375 - 2s/epoch - 605ms/step
# Epoch 12/100
# 4/4 - 2s - loss: 0.3174 - accuracy: 0.8750 - val_loss: 0.1791 - val_accuracy: 0.9375 - 2s/epoch - 401ms/step
# Epoch 13/100
# 4/4 - 2s - loss: 0.5692 - accuracy: 0.8125 - val_loss: 0.3198 - val_accuracy: 1.0000 - 2s/epoch - 398ms/step
# Epoch 14/100
# 4/4 - 2s - loss: 0.3624 - accuracy: 0.8594 - val_loss: 0.1014 - val_accuracy: 1.0000 - 2s/epoch - 384ms/step
# Epoch 15/100
# 4/4 - 2s - loss: 0.3192 - accuracy: 0.8750 - val_loss: 0.1219 - val_accuracy: 1.0000 - 2s/epoch - 408ms/step
# Epoch 16/100
# 4/4 - 2s - loss: 0.2491 - accuracy: 0.9219 - val_loss: 0.0618 - val_accuracy: 1.0000 - 2s/epoch - 403ms/step
# Epoch 17/100
# 4/4 - 1s - loss: 0.4873 - accuracy: 0.8281 - val_loss: 0.1808 - val_accuracy: 0.9375 - 1s/epoch - 368ms/step
# Epoch 18/100
# 4/4 - 2s - loss: 0.3051 - accuracy: 0.8750 - val_loss: 0.1060 - val_accuracy: 1.0000 - 2s/epoch - 602ms/step
# Epoch 19/100
# 4/4 - 2s - loss: 0.3406 - accuracy: 0.8906 - val_loss: 0.2158 - val_accuracy: 1.0000 - 2s/epoch - 435ms/step
# Epoch 20/100
# 4/4 - 1s - loss: 0.3101 - accuracy: 0.8750 - val_loss: 0.1893 - val_accuracy: 1.0000 - 1s/epoch - 362ms/step
# Epoch 21/100
# 4/4 - 1s - loss: 0.3029 - accuracy: 0.8750 - val_loss: 0.1181 - val_accuracy: 1.0000 - 1s/epoch - 371ms/step
# Epoch 22/100
# 4/4 - 1s - loss: 0.2574 - accuracy: 0.9464 - val_loss: 0.0448 - val_accuracy: 1.0000 - 1s/epoch - 333ms/step
# Epoch 23/100
# 4/4 - 2s - loss: 0.2224 - accuracy: 0.9062 - val_loss: 0.1155 - val_accuracy: 1.0000 - 2s/epoch - 392ms/step
# Epoch 24/100
# 4/4 - 2s - loss: 0.3013 - accuracy: 0.9107 - val_loss: 0.2868 - val_accuracy: 0.9375 - 2s/epoch - 568ms/step
# Epoch 25/100
# 4/4 - 2s - loss: 0.2147 - accuracy: 0.9375 - val_loss: 0.1263 - val_accuracy: 1.0000 - 2s/epoch - 451ms/step
# Epoch 26/100
# 4/4 - 1s - loss: 0.0943 - accuracy: 0.9844 - val_loss: 0.0379 - val_accuracy: 1.0000 - 1s/epoch - 353ms/step
# Epoch 27/100
# 4/4 - 2s - loss: 0.1354 - accuracy: 0.9219 - val_loss: 0.0598 - val_accuracy: 1.0000 - 2s/epoch - 389ms/step
# Epoch 28/100
# 4/4 - 1s - loss: 0.0642 - accuracy: 0.9821 - val_loss: 0.0163 - val_accuracy: 1.0000 - 1s/epoch - 367ms/step
# Epoch 29/100
# 4/4 - 1s - loss: 0.2292 - accuracy: 0.9062 - val_loss: 0.0202 - val_accuracy: 1.0000 - 1s/epoch - 364ms/step
# Epoch 30/100
# 4/4 - 2s - loss: 0.2370 - accuracy: 0.9375 - val_loss: 0.0722 - val_accuracy: 1.0000 - 2s/epoch - 405ms/step
# Epoch 31/100
# 4/4 - 2s - loss: 0.2817 - accuracy: 0.8750 - val_loss: 0.1066 - val_accuracy: 1.0000 - 2s/epoch - 487ms/step
# Epoch 32/100
# 4/4 - 2s - loss: 0.1350 - accuracy: 0.9531 - val_loss: 0.0610 - val_accuracy: 1.0000 - 2s/epoch - 563ms/step
# Epoch 33/100
# 4/4 - 2s - loss: 0.2215 - accuracy: 0.9062 - val_loss: 0.1384 - val_accuracy: 0.9375 - 2s/epoch - 394ms/step
# Epoch 34/100
# 4/4 - 1s - loss: 0.1812 - accuracy: 0.9375 - val_loss: 0.0895 - val_accuracy: 1.0000 - 1s/epoch - 361ms/step
# Epoch 35/100
# 4/4 - 2s - loss: 0.1088 - accuracy: 0.9688 - val_loss: 0.0586 - val_accuracy: 1.0000 - 2s/epoch - 408ms/step
# Epoch 36/100
# 4/4 - 1s - loss: 0.0761 - accuracy: 0.9821 - val_loss: 0.0403 - val_accuracy: 1.0000 - 1s/epoch - 363ms/step
# Epoch 37/100
# 4/4 - 2s - loss: 0.2092 - accuracy: 0.9688 - val_loss: 0.0444 - val_accuracy: 1.0000 - 2s/epoch - 437ms/step
# Epoch 38/100
# 4/4 - 2s - loss: 0.1199 - accuracy: 0.9531 - val_loss: 0.0980 - val_accuracy: 1.0000 - 2s/epoch - 611ms/step
# Epoch 39/100
# 4/4 - 1s - loss: 0.1366 - accuracy: 0.9375 - val_loss: 0.1309 - val_accuracy: 0.9375 - 1s/epoch - 366ms/step
# Epoch 40/100
# 4/4 - 1s - loss: 0.2335 - accuracy: 0.8906 - val_loss: 0.0847 - val_accuracy: 1.0000 - 1s/epoch - 356ms/step
# Epoch 41/100
# 4/4 - 2s - loss: 0.1107 - accuracy: 0.9531 - val_loss: 0.0450 - val_accuracy: 1.0000 - 2s/epoch - 393ms/step
# Epoch 42/100
# 4/4 - 1s - loss: 0.0884 - accuracy: 0.9375 - val_loss: 0.0391 - val_accuracy: 1.0000 - 1s/epoch - 363ms/step
# Epoch 43/100
# 4/4 - 2s - loss: 0.3000 - accuracy: 0.8571 - val_loss: 0.0676 - val_accuracy: 1.0000 - 2s/epoch - 473ms/step
# Epoch 44/100
# 4/4 - 2s - loss: 0.1394 - accuracy: 0.9219 - val_loss: 0.0844 - val_accuracy: 1.0000 - 2s/epoch - 550ms/step
# Epoch 45/100
# 4/4 - 2s - loss: 0.1862 - accuracy: 0.9531 - val_loss: 0.1040 - val_accuracy: 1.0000 - 2s/epoch - 398ms/step
# Epoch 46/100
# 4/4 - 2s - loss: 0.1031 - accuracy: 0.9844 - val_loss: 0.0380 - val_accuracy: 1.0000 - 2s/epoch - 399ms/step
# Epoch 47/100
# 4/4 - 2s - loss: 0.1257 - accuracy: 0.9219 - val_loss: 0.1714 - val_accuracy: 0.9375 - 2s/epoch - 411ms/step
# Epoch 48/100
# 4/4 - 2s - loss: 0.1320 - accuracy: 0.9375 - val_loss: 0.2072 - val_accuracy: 0.9375 - 2s/epoch - 416ms/step
# Epoch 49/100
# 4/4 - 3s - loss: 0.1962 - accuracy: 0.9464 - val_loss: 0.0527 - val_accuracy: 1.0000 - 3s/epoch - 713ms/step
# Epoch 50/100
# 4/4 - 2s - loss: 0.0946 - accuracy: 0.9844 - val_loss: 0.1459 - val_accuracy: 0.9375 - 2s/epoch - 402ms/step
# Epoch 51/100
# 4/4 - 2s - loss: 0.1578 - accuracy: 0.9219 - val_loss: 0.2360 - val_accuracy: 0.9375 - 2s/epoch - 390ms/step
# Epoch 52/100
# 4/4 - 2s - loss: 0.1086 - accuracy: 0.9375 - val_loss: 0.3277 - val_accuracy: 0.9375 - 2s/epoch - 424ms/step
# Epoch 53/100
# 4/4 - 2s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1699 - val_accuracy: 0.9375 - 2s/epoch - 382ms/step
# Epoch 54/100
# 4/4 - 2s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9375 - 2s/epoch - 408ms/step
# Epoch 55/100
# 4/4 - 2s - loss: 0.0651 - accuracy: 0.9688 - val_loss: 0.0230 - val_accuracy: 1.0000 - 2s/epoch - 608ms/step
# Epoch 56/100
# 4/4 - 2s - loss: 0.1973 - accuracy: 0.9219 - val_loss: 0.0604 - val_accuracy: 1.0000 - 2s/epoch - 491ms/step
# Epoch 57/100
# 4/4 - 2s - loss: 0.0902 - accuracy: 0.9643 - val_loss: 0.0409 - val_accuracy: 1.0000 - 2s/epoch - 378ms/step
# Epoch 58/100
# 4/4 - 1s - loss: 0.1742 - accuracy: 0.9643 - val_loss: 0.0286 - val_accuracy: 1.0000 - 1s/epoch - 350ms/step
# Epoch 59/100
# 4/4 - 2s - loss: 0.1006 - accuracy: 0.9375 - val_loss: 0.0030 - val_accuracy: 1.0000 - 2s/epoch - 388ms/step
# Epoch 60/100
# 4/4 - 2s - loss: 0.1154 - accuracy: 0.9531 - val_loss: 0.0247 - val_accuracy: 1.0000 - 2s/epoch - 375ms/step
# Epoch 61/100
# 4/4 - 3s - loss: 0.0376 - accuracy: 0.9844 - val_loss: 0.0083 - val_accuracy: 1.0000 - 3s/epoch - 643ms/step
# Epoch 62/100
# 4/4 - 2s - loss: 0.0575 - accuracy: 0.9844 - val_loss: 0.0201 - val_accuracy: 1.0000 - 2s/epoch - 551ms/step
# Epoch 63/100
# 4/4 - 2s - loss: 0.1817 - accuracy: 0.9375 - val_loss: 0.0302 - val_accuracy: 1.0000 - 2s/epoch - 393ms/step
# Epoch 64/100
# 4/4 - 2s - loss: 0.1778 - accuracy: 0.8906 - val_loss: 0.0244 - val_accuracy: 1.0000 - 2s/epoch - 416ms/step
# Epoch 65/100
# 4/4 - 2s - loss: 0.0597 - accuracy: 0.9844 - val_loss: 0.0139 - val_accuracy: 1.0000 - 2s/epoch - 382ms/step
# Epoch 66/100
# 4/4 - 1s - loss: 0.1353 - accuracy: 0.9643 - val_loss: 0.0231 - val_accuracy: 1.0000 - 1s/epoch - 365ms/step
# Epoch 67/100
# 4/4 - 2s - loss: 0.1116 - accuracy: 0.9531 - val_loss: 0.0576 - val_accuracy: 1.0000 - 2s/epoch - 380ms/step
# Epoch 68/100
# 4/4 - 2s - loss: 0.1130 - accuracy: 0.9375 - val_loss: 0.0427 - val_accuracy: 1.0000 - 2s/epoch - 545ms/step
# Epoch 69/100
# 4/4 - 2s - loss: 0.0696 - accuracy: 0.9821 - val_loss: 0.1496 - val_accuracy: 0.8750 - 2s/epoch - 610ms/step
# Epoch 70/100
# 4/4 - 2s - loss: 0.0559 - accuracy: 0.9688 - val_loss: 0.0184 - val_accuracy: 1.0000 - 2s/epoch - 428ms/step
# Epoch 71/100
# 4/4 - 2s - loss: 0.1026 - accuracy: 0.9844 - val_loss: 0.0710 - val_accuracy: 0.9375 - 2s/epoch - 381ms/step
# Epoch 72/100
# 4/4 - 2s - loss: 0.1201 - accuracy: 0.9375 - val_loss: 0.0407 - val_accuracy: 1.0000 - 2s/epoch - 417ms/step
# Epoch 73/100
# 4/4 - 2s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9375 - 2s/epoch - 406ms/step
# Epoch 74/100
# 4/4 - 2s - loss: 0.0872 - accuracy: 0.9688 - val_loss: 0.0048 - val_accuracy: 1.0000 - 2s/epoch - 400ms/step
# Epoch 75/100
# 4/4 - 2s - loss: 0.0836 - accuracy: 0.9688 - val_loss: 0.0234 - val_accuracy: 1.0000 - 2s/epoch - 570ms/step
# Epoch 76/100
# 4/4 - 2s - loss: 0.1124 - accuracy: 0.9531 - val_loss: 0.1690 - val_accuracy: 0.9375 - 2s/epoch - 606ms/step
# Epoch 77/100
# 4/4 - 2s - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 1.0000 - 2s/epoch - 387ms/step
# Epoch 78/100
# 4/4 - 1s - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000 - 1s/epoch - 364ms/step
# Epoch 79/100
# 4/4 - 2s - loss: 0.1292 - accuracy: 0.9531 - val_loss: 0.0039 - val_accuracy: 1.0000 - 2s/epoch - 395ms/step
# Epoch 80/100
# 4/4 - 1s - loss: 0.0738 - accuracy: 0.9688 - val_loss: 0.0169 - val_accuracy: 1.0000 - 1s/epoch - 362ms/step
# Epoch 81/100
# 4/4 - 1s - loss: 0.0355 - accuracy: 0.9821 - val_loss: 0.0060 - val_accuracy: 1.0000 - 1s/epoch - 360ms/step
# Epoch 82/100
# 4/4 - 2s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000 - 2s/epoch - 603ms/step
# Epoch 83/100
# 4/4 - 2s - loss: 0.1356 - accuracy: 0.9643 - val_loss: 0.0383 - val_accuracy: 1.0000 - 2s/epoch - 457ms/step
# Epoch 84/100
# 4/4 - 2s - loss: 0.0645 - accuracy: 0.9688 - val_loss: 0.0263 - val_accuracy: 1.0000 - 2s/epoch - 414ms/step
# Epoch 85/100
# 4/4 - 2s - loss: 0.0789 - accuracy: 0.9844 - val_loss: 0.0727 - val_accuracy: 1.0000 - 2s/epoch - 414ms/step
# Epoch 86/100
# 4/4 - 1s - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - 1s/epoch - 360ms/step
# Epoch 87/100
# 4/4 - 2s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - 2s/epoch - 406ms/step
# Epoch 88/100
# 4/4 - 2s - loss: 0.0556 - accuracy: 0.9821 - val_loss: 0.0677 - val_accuracy: 1.0000 - 2s/epoch - 580ms/step
# Epoch 89/100
# 4/4 - 2s - loss: 0.1510 - accuracy: 0.9531 - val_loss: 0.0613 - val_accuracy: 1.0000 - 2s/epoch - 431ms/step
# Epoch 90/100
# 4/4 - 2s - loss: 0.1382 - accuracy: 0.9531 - val_loss: 0.0695 - val_accuracy: 1.0000 - 2s/epoch - 401ms/step
# Epoch 91/100
# 4/4 - 2s - loss: 0.1572 - accuracy: 0.9375 - val_loss: 0.0332 - val_accuracy: 1.0000 - 2s/epoch - 382ms/step
# Epoch 92/100
# 4/4 - 1s - loss: 0.1007 - accuracy: 0.9688 - val_loss: 0.0346 - val_accuracy: 1.0000 - 1s/epoch - 368ms/step
# Epoch 93/100
# 4/4 - 2s - loss: 0.0402 - accuracy: 0.9844 - val_loss: 0.0242 - val_accuracy: 1.0000 - 2s/epoch - 378ms/step
# Epoch 94/100
# 4/4 - 2s - loss: 0.0418 - accuracy: 0.9844 - val_loss: 0.0160 - val_accuracy: 1.0000 - 2s/epoch - 435ms/step
# Epoch 95/100
# 4/4 - 2s - loss: 0.0426 - accuracy: 0.9844 - val_loss: 0.0053 - val_accuracy: 1.0000 - 2s/epoch - 610ms/step
# Epoch 96/100
# 4/4 - 2s - loss: 0.3436 - accuracy: 0.9219 - val_loss: 0.0355 - val_accuracy: 1.0000 - 2s/epoch - 485ms/step
# Epoch 97/100
# 4/4 - 2s - loss: 0.0863 - accuracy: 0.9688 - val_loss: 0.0396 - val_accuracy: 1.0000 - 2s/epoch - 411ms/step
# Epoch 98/100
# 4/4 - 2s - loss: 0.0506 - accuracy: 0.9688 - val_loss: 0.0506 - val_accuracy: 1.0000 - 2s/epoch - 391ms/step
# Epoch 99/100
# 4/4 - 1s - loss: 0.0615 - accuracy: 0.9821 - val_loss: 0.0892 - val_accuracy: 0.9375 - 1s/epoch - 331ms/step
# Epoch 100/100
# 4/4 - 2s - loss: 0.0315 - accuracy: 0.9844 - val_loss: 0.0183 - val_accuracy: 1.0000 - 2s/epoch - 411ms/step

# %%
# 모델 성능 평가
model.evaluate(train_generator)
# Out:
# 18/18 [==============================] - 2s 128ms/step - loss: 0.0666 - accuracy: 0.9714
# [0.06661106646060944, 0.9714285731315613]

# %%
model.evaluate(validation_generator)
# Out:
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0109 - accuracy: 1.0000
# [0.010852302424609661, 1.0]

# %%
# 정확도 및 손실 시각화
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# 이제 테스트 이미지 분류
import numpy as np
from keras.preprocessing import image

# 테스트용 O 이미지 경로 설정
test_dir = './OX_images/test/'
test_o_dir = os.path.join(test_dir, 'O/')
test_o_filenames = os.listdir(test_o_dir)
test_o_filenames

# 테스트용 X 이미지 경로 설정
test_dir = './OX_images/test/'
test_x_dir = os.path.join(test_dir, 'X/')
test_x_filenames = os.listdir(test_x_dir)
test_x_filenames

# O,X를 key로, 이미지 파일 이름들을 value로 dictionary 생성
dic_ox_filenames = {}
dic_ox_filenames['O'] = test_o_filenames
dic_ox_filenames['X'] = test_x_filenames

# O/X 분류 테스트
for ox, filenames in dic_ox_filenames.items():
    fig = plt.figure(figsize=(16,20))
    rows, cols = 1, 20
    for i, fn in enumerate(filenames):
        path = test_dir + ox + '/' + fn
        test_img = image.load_img(path, color_mode='grayscale', target_size=(150, 150), interpolation='bilinear')
        x = image.img_to_array(test_img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        classes = model.predict(images, batch_size=10)
        print(rows, cols, i+1)
        fig.add_subplot(rows, cols+1, i+1)
        if classes[0]==0:
            plt.title(fn + " is O")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
        else:
            plt.title(fn + " is X")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
    plt.show();
# Out:
# 1/1 [==============================] - 0s 88ms/step
# 1 20 1
# 1/1 [==============================] - 0s 27ms/step
# 1 20 2
# 1/1 [==============================] - 0s 28ms/step
# 1 20 3
# 1/1 [==============================] - 0s 30ms/step
# 1 20 4
# 1/1 [==============================] - 0s 30ms/step
# 1 20 5
# 1/1 [==============================] - 0s 28ms/step
# 1 20 6
# 1/1 [==============================] - 0s 29ms/step
# 1 20 7
# 1/1 [==============================] - 0s 29ms/step
# 1 20 8
# 1/1 [==============================] - 0s 32ms/step
# 1 20 9
# 1/1 [==============================] - 0s 31ms/step
# 1 20 10
# 1/1 [==============================] - 0s 28ms/step
# 1 20 11
# 1/1 [==============================] - 0s 27ms/step
# 1 20 12
# 1/1 [==============================] - 0s 28ms/step
# 1 20 13
# 1/1 [==============================] - 0s 29ms/step
# 1 20 14
# 1/1 [==============================] - 0s 29ms/step
# 1 20 15
# 1/1 [==============================] - 0s 31ms/step
# 1 20 16
# 1/1 [==============================] - 0s 27ms/step
# 1 20 17
# 1/1 [==============================] - 0s 29ms/step
# 1 20 18
# 1/1 [==============================] - 0s 30ms/step
# 1 20 19
# 1/1 [==============================] - 0s 28ms/step
# 1 20 20
# 1/1 [==============================] - 0s 26ms/step
# 1 20 1
# 1/1 [==============================] - 0s 28ms/step
# 1 20 2
# 1/1 [==============================] - 0s 41ms/step
# 1 20 3
# 1/1 [==============================] - 0s 27ms/step
# 1 20 4
# 1/1 [==============================] - 0s 29ms/step
# 1 20 5
# 1/1 [==============================] - 0s 25ms/step
# 1 20 6
# 1/1 [==============================] - 0s 26ms/step
# 1 20 7
# 1/1 [==============================] - 0s 27ms/step
# 1 20 8
# 1/1 [==============================] - 0s 31ms/step
# 1 20 9
# 1/1 [==============================] - 0s 32ms/step
# 1 20 10
# 1/1 [==============================] - 0s 26ms/step
# 1 20 11
# 1/1 [==============================] - 0s 26ms/step
# 1 20 12
# 1/1 [==============================] - 0s 41ms/step
# 1 20 13
# 1/1 [==============================] - 0s 27ms/step
# 1 20 14
# 1/1 [==============================] - 0s 28ms/step
# 1 20 15
# 1/1 [==============================] - 0s 33ms/step
# 1 20 16
# 1/1 [==============================] - 0s 25ms/step
# 1 20 17
# 1/1 [==============================] - 0s 31ms/step
# 1 20 18
# 1/1 [==============================] - 0s 33ms/step
# 1 20 19
# 1/1 [==============================] - 0s 28ms/step
# 1 20 20

# %%
# 모델 성능 평가
model.evaluate(test_generator)
# Out:
# 10/10 [==============================] - 0s 29ms/step - loss: 0.1728 - accuracy: 0.9250
# [0.17282834649085999, 0.925000011920929]

# %%
# 모델 저장
model.save('ox_class_cnn.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
