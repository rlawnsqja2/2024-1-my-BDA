# %% [markdown]
# <a href="https://colab.research.google.com/github/moolgutree/2024-1-my-BDA/blob/main/%EA%B3%BC%EC%A0%9C/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EA%B3%BC%EC%A0%9C_03%EC%A1%B0_20221667_%EC%9D%B4%EC%9D%80%EC%A4%80_20231559_%EA%B9%80%EC%A4%80%EB%B2%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 타이타닉 데이터

# %%
import sys

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import csv

# %%
import matplotlib.pyplot as plt
# !pip install koreanize_matplotlib
import koreanize_matplotlib
# Out:
# Requirement already satisfied: koreanize_matplotlib in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.1.1)
# Requirement already satisfied: matplotlib in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from koreanize_matplotlib) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->koreanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\김준범\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)

# %%
# 그림 선명하게
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# #**타이타닉 데이터 분석**

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# 남성 여성 탑승자 수
sns.countplot(titanic, x="sex", hue="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# 객실 등급별 탑승자 수
sns.countplot(titanic, x="class", hue="class");

# %%
# 데크별 탑승자 수
sns.countplot(titanic, x="deck", hue="deck");

# %%
# 연령별 탑승자 수
plt.figure(figsize=(8, 5))
sns.distplot(titanic['age'], bins=25)
# Out:
# C:\TempFolder\ipykernel_12804\4023525854.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'], bins=25)
# <Axes: xlabel='age', ylabel='Density'>

# %%
# 연령별 생존비율
sur = titanic[titanic['survived'] == 1]
dead = titanic[titanic['survived'] == 0]

plt.figure(figsize=(8, 5))
sns.distplot(sur['age'], bins=25)
sns.distplot(dead['age'], bins=25)
# Out:
# C:\TempFolder\ipykernel_12804\92545012.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sur['age'], bins=25)
# C:\TempFolder\ipykernel_12804\92545012.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dead['age'], bins=25)
# <Axes: xlabel='age', ylabel='Density'>

# %%
# 객실 등급별 생존/사망자 수 
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].set_title("객실등급별 탑승수 \n", size=15)
sns.countplot(titanic, x="pclass", hue="class", ax=axes[0])

axes[1].set_title("객실등급별 생존/사망자 수 \n", size=15)
sns.countplot(titanic, x="pclass", hue="alive", ax=axes[1]);

# %%
# 객실등급별 생존률
sur = titanic[['class', 'survived']].groupby(['class']).mean().plot.bar()
sur.set_title('객실등급별 생존률', size=15)
# Out:
# C:\TempFolder\ipykernel_12804\596709619.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sur = titanic[['class', 'survived']].groupby(['class']).mean().plot.bar()
# Text(0.5, 1.0, '객실등급별 생존률')

# %%
# 생존 비율

plt.figure(figsize=(8, 5))
titanic["alive"].value_counts().plot.pie(explode=[0, 0.08], 
                                          shadow=True,
                                          autopct='%1.1f%%'
                                          )
# Out:
# <Axes: ylabel='count'>

# %%
# 남자와 여자의 생존 비율
sns.countplot(titanic, x = "who", hue = "alive", stat = "percent");

# %%
# 항구에서 탑승한 승객의 수
sns.countplot(titanic, x="embark_town", hue="embark_town");

# %%
# 티켓 값에 따른 생존/사망 비율
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(titanic[titanic['survived']==1]['fare'], ax=ax)
sns.kdeplot(titanic[titanic['survived']==0]['fare'], ax=ax)
 
ax.set(xlim=(0, titanic['fare'].max()))
ax.legend(['alive', 'dead'])
 
plt.show()

# %%
titanic.fare.isna().sum()
# Out:
# 0

# %%
titanic.sex.isna().sum()
# Out:
# 0

# %%
titanic.age.isna().sum()
# Out:
# 177

# %%
titanic.alive.isna().sum()
# Out:
# 0

# %%
titanic.embark_town.isna().sum()
# Out:
# 2

# %% [markdown]
# #**해양쓰레기 데이터 분석**

# %%
trash = pd.read_csv('해양환경공단_해양쓰레기 조사_지역별_20221231.txt', sep = ',')
trash
# Out:
#       구분   조사면적    추정량
# 0    평택시      0    0.0
# 1    안산시      0    0.0
# 2    시흥시      0    0.0
# 3    김포시      0    0.0
# 4    화성시      0    0.0
# ..   ...    ...    ...
# 85   부안군      0    0.0
# 86   고창군      0    0.0
# 87   김제시      0    0.0
# 88   제주시  15226  212.9
# 89  서귀포시  10064  125.3
#
# [90 rows x 3 columns]

# %%
경기도 = trash.drop(range(7, 90))
경기도
# Out:
#        구분  조사면적  추정량
# 0     평택시     0  0.0
# 1     안산시     0  0.0
# 2     시흥시     0  0.0
# 3     김포시     0  0.0
# 4     화성시     0  0.0
# 5     군포시     0  0.0
# 6  안산환경재단     0  0.0

# %%
경기도 = 경기도.sum().to_frame()  # 경기도지역의 해양쓰레기 합산
경기도
# Out:
#                              0
# 구분    평택시안산시시흥시김포시화성시군포시안산환경재단
# 조사면적                         0
# 추정량                        0.0

# %%
경기도 = 경기도.transpose()  # 행렬변환
경기도
# Out:
#                          구분 조사면적  추정량
# 0  평택시안산시시흥시김포시화성시군포시안산환경재단    0  0.0

# %%
경기도.loc[0, '구분'] = '경기도'
경기도
# Out:
#     구분 조사면적  추정량
# 0  경기도    0  0.0

# %%
인천광역시 = trash.drop(range(0, 7)).drop(range(15, 90))
인천광역시
# Out:
#          구분  조사면적    추정량
# 7        중구  1060  100.0
# 8       남동구     0    0.0
# 9        동구     0    0.0
# 10       서구     0    0.0
# 11      강화군     0    0.0
# 12      옹진군     0    0.0
# 13      연수구     0    0.0
# 14  인천해양경찰서     0    0.0

# %%
인천광역시 = 인천광역시.sum().to_frame().transpose()
인천광역시.loc[0, '구분'] = '인천광역시'
인천광역시
# Out:
#       구분  조사면적    추정량
# 0  인천광역시  1060  100.0

# %%
강원도 = trash.drop(range(0, 15)).drop(range(22, 90))
강원도
# Out:
#       구분  조사면적   추정량
# 15   강릉시    30  11.0
# 16   속초시     0   0.0
# 17   고성군     0   0.0
# 18   동해시     0   0.0
# 19   삼척시   300   2.2
# 20   양양군  1500   3.0
# 21  강원도청     0   0.0

# %%
강원도 = 강원도.sum().to_frame().transpose()
강원도.loc[0, '구분'] = '강원도'
강원도
# Out:
#     구분  조사면적   추정량
# 0  강원도  1830  16.2

# %%
충청도 = trash.drop(range(0, 22)).drop(range(29, 90))
충청도
# Out:
#      구분  조사면적    추정량
# 22  보령시     0    0.0
# 23  아산시     0    0.0
# 24  서산시   350  123.1
# 25  서천군    25    0.0
# 26  홍성군     0    0.0
# 27  태안군    20    0.0
# 28  당진시     0    0.0

# %%
충청도 = 충청도.sum().to_frame().transpose()
충청도.loc[0, '구분'] = '충청도'
충청도
# Out:
#     구분 조사면적    추정량
# 0  충청도  395  123.1

# %%
부산광역시 = trash.drop(range(0, 29)).drop(range(43, 90))
부산광역시
# Out:
#               구분  조사면적    추정량
# 29            중구     0    0.0
# 30            서구    10    8.5
# 31            동구     0    0.0
# 32           영도구  2573   43.8
# 33            남구  2030   17.7
# 34            북구     0    0.0
# 35          해운대구     0    0.0
# 36           사하구  3314   78.1
# 37           강서구    50  160.0
# 38           수영구     0    0.0
# 39           사상구     0    0.0
# 40           기장군     0    0.0
# 41       항만관리사업소     0    0.0
# 42  부산광역시낙동강관리본부     0    0.0

# %%
부산광역시 = 부산광역시.sum().to_frame().transpose()
부산광역시.loc[0, '구분'] = '부산광역시'
부산광역시
# Out:
#       구분  조사면적    추정량
# 0  부산광역시  7977  308.1

# %%
울산광역시 = trash.drop(range(0, 43)).drop(range(48, 90))
울산광역시
# Out:
#      구분  조사면적  추정량
# 43   남구    30  9.6
# 44   동구     0  0.0
# 45   북구     0  0.0
# 46  울주군     0  0.0
# 47   중구     0  0.0

# %%
울산광역시 = 울산광역시.sum().to_frame().transpose()
울산광역시.loc[0, '구분'] = '울산광역시'
울산광역시
# Out:
#       구분 조사면적  추정량
# 0  울산광역시   30  9.6

# %%
경상도 = trash.drop(range(0, 48)).drop(range(65, 90))
경상도
# Out:
#             구분  조사면적    추정량
# 48         포항시  3000    4.0
# 49         경주시     0    0.0
# 50         영덕군    50    1.0
# 51         울진군     0    0.0
# 52         울릉군     0    0.0
# 53         창원시     0    0.0
# 54   창원시 마산합포구     0    0.0
# 55     창원시 성산구     0    0.0
# 56     창원시 진해구     0    0.0
# 57  창원시 마산회원구청     0    0.0
# 58     창원해양경찰서     0    0.0
# 59         통영시   755  449.0
# 60         사천시  1050  260.5
# 61         거제시  1500   17.0
# 62         고성군     0    0.0
# 63         남해군     0    0.0
# 64         하동군    30    9.6

# %%
경상도 = 경상도.sum().to_frame().transpose()
경상도.loc[0, '구분'] = '경상도'
경상도
# Out:
#     구분  조사면적    추정량
# 0  경상도  6385  741.1

# %%
전라도 = trash.drop(range(0, 65)).drop(range(88, 90))
전라도
# Out:
#             구분  조사면적    추정량
# 65         목포시     0    0.0
# 66         여수시   500  376.2
# 67     여수해양경찰서     0    0.0
# 68         순천시     0    0.0
# 69         광양시    16    0.0
# 70  광양만민관산학협의회     0    0.0
# 71         고흥군    20    0.0
# 72         보성군     0    0.0
# 73         장흥군     0    0.0
# 74         강진군   120   31.3
# 75         해남군    10    4.4
# 76         영암군     0    0.0
# 77         무안군     0    0.0
# 78         함평군     0    0.0
# 79         영광군     0    0.0
# 80         완도군  2710   86.3
# 81         진도군    40    4.4
# 82         신안군     0    0.0
# 83         울진군     0    0.0
# 84         군산시    50   79.8
# 85         부안군     0    0.0
# 86         고창군     0    0.0
# 87         김제시     0    0.0

# %%
전라도 = 전라도.sum().to_frame().transpose()
전라도.loc[0, '구분'] = '전라도'
전라도
# Out:
#     구분  조사면적    추정량
# 0  전라도  3466  582.4

# %%
제주도 = trash.drop(range(0, 88))
제주도
# Out:
#       구분   조사면적    추정량
# 88   제주시  15226  212.9
# 89  서귀포시  10064  125.3

# %%
제주도 = 제주도.sum().to_frame().transpose()
제주도.loc[0, '구분'] = '제주도'
제주도
# Out:
#     구분   조사면적    추정량
# 0  제주도  25290  338.2

# %%
전국_해양쓰레기_조사 = [경기도, 인천광역시, 강원도, 충청도, 부산광역시, 울산광역시, 경상도, 전라도, 제주도]
전국_해양쓰레기_조사 = pd.concat(전국_해양쓰레기_조사, ignore_index=True)
전국_해양쓰레기_조사
# Out:
#       구분   조사면적    추정량
# 0    경기도      0    0.0
# 1  인천광역시   1060  100.0
# 2    강원도   1830   16.2
# 3    충청도    395  123.1
# 4  부산광역시   7977  308.1
# 5  울산광역시     30    9.6
# 6    경상도   6385  741.1
# 7    전라도   3466  582.4
# 8    제주도  25290  338.2

# %%
plt.figure(figsize=(8,5))
sns.barplot(전국_해양쓰레기_조사, x="구분", y="조사면적", hue="조사면적");

# %%
plt.figure(figsize=(8,5))
sns.barplot(전국_해양쓰레기_조사, x="구분", y="추정량", hue="추정량");

# %%
plt.figure(figsize=(8,5))
sns.barplot(전국_해양쓰레기_조사, x="구분", y="추정량", hue="조사면적");

# %%
data = 전국_해양쓰레기_조사

plt.pie(data['추정량'], labels=data['구분'], startangle=90 ,autopct='%1.1f%%')
plt.show()

# %%
sur = titanic[['class', 'survived']].groupby(['class']).mean().plot.bar()
sur.set_title('객실등급별 생존률', size=15)
# Out:
# C:\TempFolder\ipykernel_12804\2586341804.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sur = titanic[['class', 'survived']].groupby(['class']).mean().plot.bar()
# Text(0.5, 1.0, '객실등급별 생존률')

# %%
전국_해양쓰레기_조사.구분.isna().sum()
# Out:
# 0

# %%
전국_해양쓰레기_조사.조사면적.isna().sum()
# Out:
# 0

# %%
전국_해양쓰레기_조사.추정량.isna().sum()
# Out:
# 0

# %%
''' 데이터 출처 https://www.data.go.kr/data/15069295/fileData.do
공공데이터포털 해양환경공단_해양쓰레기 조사_지역별 '''
# 메모장으로 인코딩 변환
